# %% [markdown]
# Perform basic cleaning on Yelp Dataset 8 and write to SQL table.
# * Turn json objects into rows.
# * Discard non-restaurant rows.
# * Convert to pandas dataframe.
# * Write dataframe to SQL table.

# %%
import json
import pandas as pd
import psycopg2
import sqlalchemy
import logging

from sqlalchemy import create_engine, inspect

PSQL = 'postgres://{}@localhost:5432/rpred'

logging.basicConfig(level=logging.INFO)

# %%
# Yelp's json files are screwy, so I have to fix them a little bit.
# {}{}{}{} --> [{},{},{},{}]
# Then discard anything that isn't a restaurant. 
def clean_restaurant_json(filename):
    logging.info('Reading {}'.format(filename))
    json_str = ""
    with open(filename, "r") as file1:
        json_str = file1.read()
    items = []
    len_json = len(json_str.split("\n"))
    for row in json_str.split("\n"):
        if is_restaurant(row):
            items.append(row)
    logging.info('{} valid items out of {}'.format(len(items), len_json))
    return [json.loads(i) for i in items]

def is_restaurant(row):
    return ((row.find("Restaurants") > 0 or 
            row.find("Food ") > 0 or 
            row.find("Cafe") > 0 or 
            row.find("Bakeries") > 0) and row.find("Grocery") < 0)

def write_to_file(json, filename):
    with open(filename, "w") as file:
        file.write(json)

# %%
yelp_json = clean_restaurant_json("../data/yelp8/yelp_academic_dataset_business.json")

print(len(yelp_json))

df = pd.DataFrame(yelp_json)
df.head()
# Out:
# INFO:root:Reading ../data/yelp8/yelp_academic_dataset_business.json
# INFO:root:27913 valid items out of 85902
# 27913
#                                           attributes             business_id  \
# 0  {'Take-out': True, 'Drive-Thru': False, 'Good ...  5UmKMjUEUNdYWqANhGckJw
# 1  {'Alcohol': 'full_bar', 'Noise Level': 'averag...  mVHrayjG3uZ_RLHkLj-AMg
# 2  {'Alcohol': 'full_bar', 'Noise Level': 'loud',...  KayYbHCt-RkbGcPdGOThNg
# 3  {'Take-out': True, 'Drive-Thru': False, 'Good ...  wJr6kSA5dchdgOdwH6dZ2w
# 4  {'Alcohol': 'full_bar', 'Noise Level': 'averag...  fNGIbpazjTRdXgwRY_NIXA
#
#                                           categories        city  \
# 0                           [Fast Food, Restaurants]  Dravosburg
# 1  [Bars, American (New), Nightlife, Lounges, Res...    Braddock
# 2  [Bars, American (Traditional), Nightlife, Rest...    Carnegie
# 3  [Burgers, Breakfast & Brunch, American (Tradit...    Carnegie
# 4  [Bars, American (Traditional), Nightlife, Loun...    Carnegie
#
#                                       full_address  \
# 0     4734 Lebanon Church Rd\nDravosburg, PA 15034
# 1              414 Hawkins Ave\nBraddock, PA 15104
# 2  141 Hawthorne St\nGreentree\nCarnegie, PA 15106
# 3         2100 Washington Pike\nCarnegie, PA 15106
# 4          1201 Washington Ave\nCarnegie, PA 15106
#
#                                                hours   latitude  longitude  \
# 0  {'Friday': {'close': '21:00', 'open': '11:00'}...  40.354327 -79.900706
# 1  {'Tuesday': {'close': '19:00', 'open': '10:00'...  40.408830 -79.866211
# 2  {'Monday': {'close': '02:00', 'open': '11:00'}...  40.415486 -80.067549
# 3  {'Monday': {'close': '02:00', 'open': '08:00'}...  40.387512 -80.093215
# 4  {'Monday': {'close': '23:00', 'open': '11:00'}...  40.396469 -80.084942
#
#                       name neighborhoods  open  review_count  stars state  \
# 0                Mr Hoagie            []  True             7    3.5    PA
# 1            Emil's Lounge            []  True            26    4.5    PA
# 2    Alexion's Bar & Grill   [Greentree]  True            23    4.0    PA
# 3  Kings Family Restaurant            []  True            10    3.5    PA
# 4           Rocky's Lounge            []  True            10    4.0    PA
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %%
cred = ""
with open("../credentials/localhost/jessica.txt") as credfile:
    cred = credfile.read().strip("\n")
    
cnx = create_engine(PSQL.format(cred), isolation_level='AUTOCOMMIT')

df.to_sql('yelp_8', cnx, if_exists='replace', index=False, 
                    dtype={'attributes' : sqlalchemy.types.JSON, 'hours' : sqlalchemy.types.JSON})

# %%
len(df)
# Out:
# 3919
