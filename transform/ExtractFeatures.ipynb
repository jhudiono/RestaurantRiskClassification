# %%
from sqlalchemy import create_engine, inspect
from sklearn_pandas import DataFrameMapper
import pandas as pd
from sklearn.preprocessing import LabelBinarizer
import psycopg2
import numpy as np
from fuzzywuzzy import fuzz

PSQL = 'postgres://{}@localhost:5432/rpred'

# %% [markdown]
# # TODO:
# * Extract data from hours.
# * Find if restaurant is a large chain (20+)

# %% [markdown]
# Connect to Postgres database.

# %%
cred = ""
with open("credentials/localhost/jessica.txt") as credfile:
    cred = credfile.read().strip("\n")
    
cnx = create_engine(PSQL.format(cred), isolation_level='AUTOCOMMIT')

# %% [markdown]
# Read from table.

# %%
yelp_dataset_8 = pd.read_sql_query('''SELECT 
name, full_address, city, state, review_count, stars, open, categories, attributes 
FROM yelp_dataset_8''', cnx)

# %%
# filter out grocery
X = yelp_dataset_8.drop(yelp_dataset_8[yelp_dataset_8.categories.str.contains("Grocery")].index)

open_count = len(X[X['open'] == 'True'])
closed_count = len(X[X['open'] == 'False'])
print("Open:", open_count, open_count/len(X), 
      "Closed:", closed_count, closed_count/len(X))
# Out:
# Open: 11304 0.8172353961827646 Closed: 2528 0.1827646038172354

# %%
# filter out closed stores
X.drop(X[X.open == 'False'].index, inplace=True)
X.drop(columns=['open'], inplace=True)

# %%
X.head()
# Out:
#                            name  \
# 0                     Mr Hoagie
# 2  Barb's Country Junction Cafe
# 3                 Boston Market
# 4                    McDonald's
# 5                     Starbucks
#
#                                         full_address        city state  \
# 0       4734 Lebanon Church Rd\nDravosburg  PA 15034  Dravosburg    PA
# 2          202 3rd Ave\nCarnegie\nCarnegie  PA 15106    Carnegie    PA
# 3         300 Davis Blvd\nEtna\nPittsburgh  PA 15275  Pittsburgh    PA
# 4  400 Waterfront Dr E\nHomestead\nHomestead  PA ...   Homestead    PA
# 5    270 W Bridge St\nHomestead\nHomestead  PA 15120   Homestead    PA
#
#    review_count  stars                                         categories  \
# 0             7    3.5                       ['Fast Food'  'Restaurants']
# 2             9    4.0                           ['Cafes'  'Restaurants']
# 3             3    2.5  ['American (Traditional)'  'Comfort Food'  'Ca...
# 4            12    2.0            ['Burgers'  'Fast Food'  'Restaurants']
# 5            25    3.5                           ['Food'  'Coffee & Tea']
#
#                                           attributes
# 0  {'Take-out': True  'Drive-Thru': False  'Good ...
# 2  {'Take-out': True  'Good For': {'dessert': Fal...
# 3  {'Take-out': True  'Wi-Fi': 'no'  'Alcohol': '...
# 4  {'Take-out': True  'Wi-Fi': 'free'  'Drive-Thr...
# 5  {'Take-out': True  'Wi-Fi': 'free'  'Price Ran...

# %% [markdown]
# ### Add columns for binary attributes

# %%
attrs = [
    ['takeout', 'Take-out'],
    ['alcohol', 'Alcohol'],
    ['good_for_groups', 'Good For Groups'],
    ['good_for_kids', 'Good for Kids'],
    ['credit_card', 'Accepts Credit Cards']
]

def extract_attribute(X, attr):
    X[attr[0]] = np.where(X['attributes'].str.contains("'{}': True".format(attr[1])), 1, 0)

for attr in attrs:
    extract_attribute(X, attr)
X.head()
# Out:
#                            name  \
# 0                     Mr Hoagie
# 2  Barb's Country Junction Cafe
# 3                 Boston Market
# 4                    McDonald's
# 5                     Starbucks
#
#                                         full_address        city state  \
# 0       4734 Lebanon Church Rd\nDravosburg  PA 15034  Dravosburg    PA
# 2          202 3rd Ave\nCarnegie\nCarnegie  PA 15106    Carnegie    PA
# 3         300 Davis Blvd\nEtna\nPittsburgh  PA 15275  Pittsburgh    PA
# 4  400 Waterfront Dr E\nHomestead\nHomestead  PA ...   Homestead    PA
# 5    270 W Bridge St\nHomestead\nHomestead  PA 15120   Homestead    PA
#
#    review_count  stars                                         categories  \
# 0             7    3.5                       ['Fast Food'  'Restaurants']
# 2             9    4.0                           ['Cafes'  'Restaurants']
# 3             3    2.5  ['American (Traditional)'  'Comfort Food'  'Ca...
# 4            12    2.0            ['Burgers'  'Fast Food'  'Restaurants']
# 5            25    3.5                           ['Food'  'Coffee & Tea']
#
#                                           attributes  takeout  alcohol  \
# 0  {'Take-out': True  'Drive-Thru': False  'Good ...        1        0
# 2  {'Take-out': True  'Good For': {'dessert': Fal...        1        0
# 3  {'Take-out': True  'Wi-Fi': 'no'  'Alcohol': '...        1        0
# 4  {'Take-out': True  'Wi-Fi': 'free'  'Drive-Thr...        1        0
# 5  {'Take-out': True  'Wi-Fi': 'free'  'Price Ran...        1        0
#
#    good_for_groups  good_for_kids  credit_card
# 0                1              1            1
# 2                1              1            1
# 3                0              1            1
# 4                1              1            1
# 5                0              0            1

# %% [markdown]
# ### Add columns for numeric/categorical attributes

# %%
# Price range--Extract when it exists, otherwise use Imputer. 
# 10630/11304 = 94% rows contain range price information
print("Contains price range:", len(X[X['attributes'].str.contains("'Price Range'")])/len(X))

X['price'] = X['attributes'].str.extract(r"'Price Range': (\d)+")
X[['price']] = X[['price']].fillna(value=X[['price']].mean())
X.head()
# Out:
# Contains price range: 0.9403750884642604
#                            name  \
# 0                     Mr Hoagie
# 2  Barb's Country Junction Cafe
# 3                 Boston Market
# 4                    McDonald's
# 5                     Starbucks
#
#                                         full_address        city state  \
# 0       4734 Lebanon Church Rd\nDravosburg  PA 15034  Dravosburg    PA
# 2          202 3rd Ave\nCarnegie\nCarnegie  PA 15106    Carnegie    PA
# 3         300 Davis Blvd\nEtna\nPittsburgh  PA 15275  Pittsburgh    PA
# 4  400 Waterfront Dr E\nHomestead\nHomestead  PA ...   Homestead    PA
# 5    270 W Bridge St\nHomestead\nHomestead  PA 15120   Homestead    PA
#
#    review_count  stars                                         categories  \
# 0             7    3.5                       ['Fast Food'  'Restaurants']
# 2             9    4.0                           ['Cafes'  'Restaurants']
# 3             3    2.5  ['American (Traditional)'  'Comfort Food'  'Ca...
# 4            12    2.0            ['Burgers'  'Fast Food'  'Restaurants']
# 5            25    3.5                           ['Food'  'Coffee & Tea']
#
#                                           attributes  takeout  alcohol  \
# 0  {'Take-out': True  'Drive-Thru': False  'Good ...        1        0
# 2  {'Take-out': True  'Good For': {'dessert': Fal...        1        0
# 3  {'Take-out': True  'Wi-Fi': 'no'  'Alcohol': '...        1        0
# 4  {'Take-out': True  'Wi-Fi': 'free'  'Drive-Thr...        1        0
# 5  {'Take-out': True  'Wi-Fi': 'free'  'Price Ran...        1        0
#
#    good_for_groups  good_for_kids  credit_card price  fast_food  mexican  \
# 0                1              1            1     1          1        0
# 2                1              1            1     1          0        0
# 3                0              1            1     2          0        0
# 4                1              1            1     1          1        0
# 5                0              0            1     2          0        0
#
#    chinese  bar  american  fusion
# 0        0    0         0       0
# 2        0    0         0       0
# 3        0    0         1       0
# 4        0    0         0       0
# 5        0    0         0       0

# %% [markdown]
# ### Add columns for categories

# %%
categories = [
    ['fast_food', 'Fast Food'],
    ['mexican', 'Mexican'],
    ['chinese', 'Chinese'],
    ['bar', 'Bars'],
    ['american', 'American'],
    ['fusion', 'Fusion']
]

def extract_category(X, category):
    X[category[0]] = np.where(X['categories'].str.contains(category[1]), 1, 0)
    
for c in categories:
    extract_category(X, c)
X.head()
# Out:
#                            name  \
# 0                     Mr Hoagie
# 2  Barb's Country Junction Cafe
# 3                 Boston Market
# 4                    McDonald's
# 5                     Starbucks
#
#                                         full_address        city state  \
# 0       4734 Lebanon Church Rd\nDravosburg  PA 15034  Dravosburg    PA
# 2          202 3rd Ave\nCarnegie\nCarnegie  PA 15106    Carnegie    PA
# 3         300 Davis Blvd\nEtna\nPittsburgh  PA 15275  Pittsburgh    PA
# 4  400 Waterfront Dr E\nHomestead\nHomestead  PA ...   Homestead    PA
# 5    270 W Bridge St\nHomestead\nHomestead  PA 15120   Homestead    PA
#
#    review_count  stars                                         categories  \
# 0             7    3.5                       ['Fast Food'  'Restaurants']
# 2             9    4.0                           ['Cafes'  'Restaurants']
# 3             3    2.5  ['American (Traditional)'  'Comfort Food'  'Ca...
# 4            12    2.0            ['Burgers'  'Fast Food'  'Restaurants']
# 5            25    3.5                           ['Food'  'Coffee & Tea']
#
#                                           attributes  takeout  alcohol  \
# 0  {'Take-out': True  'Drive-Thru': False  'Good ...        1        0
# 2  {'Take-out': True  'Good For': {'dessert': Fal...        1        0
# 3  {'Take-out': True  'Wi-Fi': 'no'  'Alcohol': '...        1        0
# 4  {'Take-out': True  'Wi-Fi': 'free'  'Drive-Thr...        1        0
# 5  {'Take-out': True  'Wi-Fi': 'free'  'Price Ran...        1        0
#
#    good_for_groups  good_for_kids  credit_card price  fast_food  mexican  \
# 0                1              1            1     1          1        0
# 2                1              1            1     1          0        0
# 3                0              1            1     2          0        0
# 4                1              1            1     1          1        0
# 5                0              0            1     2          0        0
#
#    chinese  bar  american  fusion
# 0        0    0         0       0
# 2        0    0         0       0
# 3        0    0         1       0
# 4        0    0         0       0
# 5        0    0         0       0

# %% [markdown]
# ### Write to features table

# %%
X['full_address'] = X['full_address'].apply(lambda s: s.replace("\n", " "))
features = ['name', 'full_address' ,'review_count', 'stars', 'bar', 'fast_food', 'mexican', 'chinese']
features += [i[0] for i in attrs]
print(features)
X[features].to_sql('features', cnx, if_exists='replace', index=False)
# Out:
# ['name', 'full_address', 'review_count', 'stars', 'bar', 'fast_food', 'mexican', 'chinese', 'takeout', 'alcohol', 'good_for_groups', 'good_for_kids', 'credit_card']

# %% [markdown]
# # Scratch

# %%
# Make categories table
df_c = pd.read_sql_query('''SELECT business_id, categories
FROM yelp_dataset_8 LIMIT 200''', cnx)

def category_list(cat):
    p = re.compile(r"'([\w\W]+)'")
    #df = pd.DataFrame(df_X.categories)
    return [p.findall(x) for x in df_X.categories]
# Out:
# 0      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 1      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 2      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 3      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 4      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 5      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 6      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 7      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 8      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 9      [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 10     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 11     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 12     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 13     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 14     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 15     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 16     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 17     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 18     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 19     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 20     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 21     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 22     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 23     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 24     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 25     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 26     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 27     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 28     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 29     [[Fast Food'  'Restaurants], [Food'  'Grocery]...
#                              ...
# 170    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 171    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 172    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 173    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 174    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 175    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 176    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 177    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 178    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 179    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 180    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 181    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 182    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 183    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 184    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 185    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 186    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 187    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 188    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 189    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 190    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 191    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 192    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 193    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 194    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 195    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 196    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 197    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 198    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# 199    [[Fast Food'  'Restaurants], [Food'  'Grocery]...
# Name: categories, Length: 200, dtype: object

# %%
category_keywords = ['sandwiches', 'fast_food', 'nightlife', 'pizza', 'bars',
                     'mexican', 'food', 'american_traditional', 'burgers', 'chinese',
                     'italian', 'american_new', 'breakfast_brunch', 'thai', 'indian',
                     'sushi', 'korean', 'mediterranean', 'japanese', 'seafood',
                     'middle_eastern', 'pakistani', 'barbeque', 'vietnamese',
                     'asian_fusion', 'diners', 'greek', 'vegetarian']

def category_list(cat):
    p = re.compile(r"'([\w\W]+)'")
    #df = pd.DataFrame(df_X.categories)
    return [p.findall(x) for x in df_X.categories]
